# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

from sklearn.ensemble import RandomForestClassifier

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("ggplot")

# %matplotlib inline

# %%
df = pd.read_csv("mushrooms.csv")

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# count          8124      8124       8124   ...                       8124
# unique            2         2         12   ...                          4
# top               c         b          b   ...                          s
# freq           6812      5612       1728   ...                       4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# ...

# %% [markdown]
# Follow the steps to classify your mushroom data!
# Question 0: Do you know which data you are trying to predict as output? Try looking at the columns of the DataFrame

# %%
#1: Make sure you convert the data into categorical data
#1  Code Hint: Remember how to use .astype("category").cat.codes?

#2: Use train_test_split to segment the data into two chunks

#3: Decide which parameters to use for your classifier. Go ahead and take a guess!
#3  Code Hint: remember that you can get a subset of a pandas DataFrame by calling df[['column1', 'column2', 'column3']]

#4: Build the classifier, call .fit(), finally, call .predict() with the x_test data to predict y

#5: Use classification_report or confusion_matrix to see the results
#5  Code Hint: Don't forget to give it y_test before y_predicted

# %%
def plot_importances(clf,columns_used):
    """Plots the important variables used in the RandomForestClassifier to help you assess
    whether or not a variable should be kept in your data
    
    Parameters:
    clf (RandomForestClassifier) - A RandomForestClassifier that you have already fit to your data
    columns_used (list) - A list of columns that you used for input data
    
    Returns:
    None"""
    plt.figure(figsize=(10,12))
    ind = np.argsort(clf.feature_importances_)
    plt.barh(range(len(clf.feature_importances_)),clf.feature_importances_[ind])
    plt.title("Variable Importance")
    plt.yticks(range(len(clf.feature_importances_)),df.drop(['class'], axis=1).columns[ind])
    plt.show()

# %% [markdown]
# # Questions to Consider:

# %% [markdown]
# 1) What should you do if a column only has one value?
#
# 2) What happens if you use every feature column in your data?
#
# 3) Can you achieve the same accuracy as 2 using less features?
#
# 4) Which features were most important? Is it consistent if you run the classifier on a different train/test split?
#
# 5) Can you build a function that takes the columns as input and builds a classifier, fits the model, determine the accuracy, and plot the important features?

# %% [markdown]
# # Turning it in

# %% [markdown]
# Make this notebook look like a solid report that you would feel happy delivering to the CCC to convince them you know what features can be used to classify the edible from the poisonous! Turn your assignment in a pdf format on LearningSuite.
