# %%
class person(object):
    def __init__(self, name, my_class):
        self.name = name
        self.my_class = my_class
    
    def __lt__(self,other):
        if self.my_class<other.my_class:
            return True
        elif self.my_class>other.my_class:
            return False
        else:
            #we want least alphabetically to be higher in rank
            return self.name>other.name
    def __le__(self,other):
        return self<other
    def __eq__(self,other):
        return False
    def __ne__(self,other):
        return True
    def __ge__(self,other):
        return other<self
    def __gt__(self,other):
        return other<self


t=int(raw_input().strip())

for a0 in range(t):
    n = int(raw_input().strip())

    people = []
    dct = {"upper":1,"middle":0,"lower":-1}     
    for i in range(n):
        x = raw_input().strip().split(" ")
        temp = x[1].split("-")
        temp = [dct[temp[i]] for i in range(len(temp))]
        num = 0.
        for k in temp:
            num = k + num/2.
        new_person = person(x[0][:-1],num)
        people.append(new_person)

    #sort by class lowest to highest, reverse alphabetical for 
    ordered = sorted(people)

    for a_person in ordered[::-1]:
        print a_person.name
    print "="*30

# %%
def problem_f():
    def value(the_class):
        if the_class == "upper":
            return "3"
        if the_class == "middle":
            return "2"
        if the_class == "lower":
            return "1"
    cases = int(raw_input())#how many cases
    for k in xrange(cases):
        people = int(raw_input())
        persons = []
        values = []
        final = []
        for j in xrange(people):
            person = raw_input().split()
            chain = person[1].split("-")
            chains = []
            for x in xrange(len(chain)):
                chain[x] = value(chain[x])
            chain = chain[::-1]
            for i in xrange(20 - len(chain)):
                chain.append("2")

            chain = "".join(chain)
            chain = int(chain)
            person[0] = person[0][:-1]

            persons.append(person[0])
            values.append(chain)

        
        while len(values) > 0:
            for y in xrange(len(values)):

                if values[y] == max(values):
                    
                    final.append(persons[y] + "\n")
                    values.remove(values[y])
                    persons.remove(persons[y])

                    break
            
        ready = "".join(final)
        print ready

# %%
#probF
t = int(raw_input)
for i in range(t):
    persons{}
    n = input()
    to_print = ""
    for j in range(n):
        li = raw_input().strip().split(":")
        persons[li[0]] = li[1].strip().replace("class","").strip().split("-")
    for person in persons.key():
        for i in range(len(persons[person])):
            if persons[person][i] == "middle":
                persons[person][i] = "2"
            if persons[person][i] == "lower":
                persons[person][i] = "1"
            if persons[person][i] == "upper":
                persons[person][i] = "3"
    final = "".join(persons[person])
    final = final[::-1]
    person

# %%
def probF():
    x = int(raw_input())
    for i in range(x):
        y = int(raw_input())        
        names = [raw_input() for i in range(y)]
        first_names = [name[0] for name in names]   
        classes = []        
        for name in names:
            name.split()
            classes.append([name[1].split('-')])

        d = {first_name: classe for (first_name, classe) in (first_names, classes)}

# %%
t = int(raw_input())
for i in range(t):
    persons = {}
    n = input()
    to_print = ""
    for j in range(n):
        li = raw_input().strip().split(":")
        persons[li[0]] = li[1].strip().replace("class","").strip().split("-")
    for person in persons.keys():
        for i in range(len(persons[person])):
            if persons[person][i] == "middle":
                persons[person][i] = "2"
            if persons[person][i] == "lower":
                persons[person][i] = "1"
            if persons[person][i] == "upper":
                persons[person][i] = "3"
        final = "".join(persons[person])
        final = final[::-1]
        persons[person] = final
    li = []
    keys = sorted(persons.keys())
    for person in keys:
        li.append(persons[person])
    max_length = len(max(li, key=len))

    for person in keys:
        if len(persons[person]) < max_length:
            while len(persons[person]) < max_length:
                persons[person] += "2"
        persons[person] = int(persons[person])
    li = sorted(persons.items(), key=lambda x: x[1], reverse=True)

    for name in li:
        print name[0]

# %%
def probF():
    t=int(raw_input())
    for i in range(t):
        persons={}
        n=input()
        to_print=""
        for j in range(n):
            li = raw_input().strip().split(":")
            persons[li0]] = li[1].strip().replace("class","")strip().split("-")
        for persons in persons.keys():
            for i in range(len(persons[person])):
                if persons[person][i] == "middle":
                    persons[person][i]="2"
                if persons[person][i] == "upper":
                    persons[person][i]="3"
                if persons[person][i] == "lower":
                    persons[person][i]="1"
            final="".join(persons[person])
            final=final[::-1]
            persons[person]=final
        li=[]
        keys=sorted(persons.keys())
        for person in keys:
            li.append
